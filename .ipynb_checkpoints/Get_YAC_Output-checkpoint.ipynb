# %%
import pandas as pd
import numpy as np

# %%
week1 = pd.read_csv('./output/yac_week1.csv')
week2 = pd.read_csv('./output/yac_week2.csv')
week3 = pd.read_csv('./output/yac_week3.csv')
week4 = pd.read_csv('./output/yac_week4.csv')
week5 = pd.read_csv('./output/yac_week5.csv')
week6 = pd.read_csv('./output/yac_week6.csv')
week7 = pd.read_csv('./output/yac_week7.csv')
week8 = pd.read_csv('./output/yac_week8.csv')
week9 = pd.read_csv('./output/yac_week9.csv')
week10 = pd.read_csv('./output/yac_week10.csv')
week11 = pd.read_csv('./output/yac_week11.csv')
week12 = pd.read_csv('./output/yac_week12.csv')
week13 = pd.read_csv('./output/yac_week13.csv')
week14 = pd.read_csv('./output/yac_week14.csv')
week15 = pd.read_csv('./output/yac_week15.csv')
week16 = pd.read_csv('./output/yac_week16.csv')
week17 = pd.read_csv('./output/yac_week17.csv')

# %%
df = pd.concat([
                week1,
                week2,
                week3,
                week4,
                week5,
                week6,
                week7,
                week8,
                week9,
                week10,
                week11,
                week12,
                week13,
                week14,
                week15,
                week16,
                week17
                ], axis=0)

# %%
df = df.rename(columns={'receiver_nflId':'nflId'})

# %%
df.columns
# Out:
# Index(['gameId', 'playId', 'frameId', 'nflId', 'closest_defender_nflId',
#        'closest_blocker_nflId', 'closest_defender_pass_caught_x',
#        'closest_defender_pass_caught_y', 'closest_defender_pass_caught_s',
#        'closest_defender_pass_caught_a', 'closest_defender_pass_caught_dis',
#        'closest_defender_pass_caught_o', 'closest_defender_pass_caught_dir',
#        'closest_defender_distance_from_target_receiver',
#        'targeted_receiver_pass_caught_x', 'targeted_receiver_pass_caught_y',
#        'targeted_receiver_pass_caught_s', 'targeted_receiver_pass_caught_a',
#        'targeted_receiver_pass_caught_dis', 'targeted_receiver_pass_caught_o',
#        'targeted_receiver_pass_caught_dir', 'closest_blocker_pass_caught_x',
#        'closest_blocker_pass_caught_y', 'closest_blocker_pass_caught_s',
#        'closest_blocker_pass_caught_a', 'closest_blocker_pass_caught_dis',
#        'closest_blocker_pass_caught_o', 'closest_blocker_pass_caught_dir',
# ...

# %%
df[['closest_defender_distance_from_target_receiver', 'closest_blocker_distance_from_closest_defender', 'targeted_receiver_distance_from_oob', 'YAC']]
# Out:
#         closest_defender_distance_from_target_receiver  \
# 0                                             7.380474
# 1                                             1.916899
# 2                                             4.983252
# 3                                             7.381389
# 4                                             1.916899
# ...                                                ...
# 275940                                        3.022201
# 275941                                        0.878009
# 275942                                       17.025657
# 275943                                        5.362024
# 275944                                        3.148412
#
#         closest_blocker_distance_from_closest_defender  \
# 0                                             9.992197
# 1                                             8.073890
# 2                                            12.802656
# 3                                             9.978637
# ...

# %%
df = df[['gameId', 'playId', 'frameId', 'nflId', 'YAC']]

# %%
# df.to_csv('output/yac.csv', index=False)
